# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from scipy.ndimage.filters import correlate,convolve

# %%
a= np.matrix([
    [0.9,0.07,0.02,0.01],
    [0,0.93,0.05,0.02],
    [0,0,0.85,0.15],
    [0,0,0,1]
])

# %%
b = np.matrix([[0.85,0.1,0.05,0]])

# %%
a.T * b.T
# Out:
# matrix([[0.765 ],
#         [0.1525],
#         [0.0645],
#         [0.018 ]])

# %%
a = np.matrix([
    [6,5,3,1],
    [3,6,2,2],
    [3,4,3,1]
])

# %%
b = np.matrix([
    [1.5,1],
    [2,2.5],
    [5,4.5],
    [16,17]
])

# %%
a * b
# Out:
# matrix([[50. , 49. ],
#         [58.5, 61. ],
#         [43.5, 43.5]])

# %%
mnist = pd.read_csv('data/mnist/mnist_train.csv')

# %%
mnist.shape
# Out:
# (60000, 785)

# %%
images = mnist.loc[:,mnist.columns != 'label']

# %%
plt.imshow(images.iloc[1,:].to_numpy().reshape(28,28),cmap='gray')

# %%
top=[
    [-1,-1,-1],
    [1,1,1],
    [0,0,0]
    ]
plt.imshow(top,cmap='gray')

# %%
corrtop =correlate(images.iloc[1,:].to_numpy().reshape(28,28),top)
plt.imshow(corrtop,cmap='gray')
