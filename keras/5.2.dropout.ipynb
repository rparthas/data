# %%
import pandas as pd
X = pd.read_csv('./data/traffic_volume_feats.csv')  
y = pd.read_csv('./data/traffic_volume_target.csv')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
def plot_and_print(model):
    history = model.fit(X_train,y_train,epochs =200,validation_data=(X_test,y_test),batch_size=50,shuffle=False,verbose=0)
    import matplotlib.pyplot as plt 
    import matplotlib
    # %matplotlib inline 
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper left')
    print("Best loss on Validation Set =", min(history.history['val_loss']))

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation

model = Sequential()
model.add(Dense(units=10,activation='relu',input_dim=X.shape[1]))
model.add(Dense(units=10,activation='relu'))
model.add(Dense(units=1))
model.compile(optimizer = 'rmsprop', loss = 'mean_squared_error')
plot_and_print(model)
# Out:
# Best loss on Validation Set = 26.109318590164186

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout

model = Sequential()
model.add(Dense(units=10,activation='relu',input_dim=X.shape[1]))
model.add(Dropout(0.1))
model.add(Dense(units=10,activation='relu'))
model.add(Dense(units=1))
model.compile(optimizer = 'rmsprop', loss = 'mean_squared_error')
plot_and_print(model)
# Out:
# Best loss on Validation Set = 42.17708973884582

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout

model = Sequential()
model.add(Dense(units=10,activation='relu',input_dim=X.shape[1]))
model.add(Dropout(0.1))
model.add(Dense(units=10,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=1))
model.compile(optimizer = 'rmsprop', loss = 'mean_squared_error')
plot_and_print(model)
# Out:
# Best loss on Validation Set = 76.16216726303101

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout

model = Sequential()
model.add(Dense(units=10,activation='relu',input_dim=X.shape[1]))
model.add(Dropout(0.2))
model.add(Dense(units=10,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=1))
model.compile(optimizer = 'rmsprop', loss = 'mean_squared_error')
plot_and_print(model)
# Out:
# Best loss on Validation Set = 114.50433731079102
